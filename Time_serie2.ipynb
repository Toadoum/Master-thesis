# %% [markdown]
# # Time serie2

# %%
import numpy as np                       
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import tree
plt.style.use('seaborn-notebook')
# %matplotlib inline

# %%
ts=pd.read_csv("ts.csv", delimiter=',')
print (ts.head())
print ('\n Data Types:')
print (ts.dtypes)
# Out:
#   Draw.up.date  daily_count
# 0   2010-01-02            1
# 1   2010-01-11            1
# 2   2010-01-18            1
# 3   2010-01-21            2
# 4   2010-01-26            7
#
#  Data Types:
# Draw.up.date    object
# daily_count      int64
# dtype: object

# %%
ts.describe()
# Out:
#        daily_count
# count   457.000000
# mean      3.105033
# std       2.942787
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max      23.000000

# %%
ts.daily_count.sum()
# Out:
# 1419

# %%
from datetime import datetime
con=ts['Draw.up.date']
ts['Draw.up.date']=pd.to_datetime(ts['Draw.up.date'])
ts.set_index('Draw.up.date', inplace=True)
#check datatype of index
ts.index
# Out:
# DatetimeIndex(['2010-01-02', '2010-01-11', '2010-01-18', '2010-01-21',
#                '2010-01-26', '2010-02-09', '2010-02-18', '2010-02-19',
#                '2010-02-22', '2010-03-05',
#                ...
#                '2019-07-05', '2019-07-15', '2019-07-23', '2019-07-26',
#                '2019-08-04', '2019-08-05', '2019-10-05', '2019-11-04',
#                '2019-12-03', '2019-12-06'],
#               dtype='datetime64[ns]', name='Draw.up.date', length=457, freq=None)

# %%
def day(day):
    val=''
    for j in str(index):
        val=val+j
        if j==' ':
            break
    
    return int(val)
day(ts.index[1]-ts.index[0])
# Out:
# 3625

# %%
def day(day):
    val=''
    for j in str(index):
        val=val+j
        if j==' ':
            break
    
    return int(val)
#day(ts.index[1]-ts.index[0])
r=range(0,457)
list_res=[]
for i in r:
    index=ts.index[i]-ts.index[0]
    list_res.append(day(index))
X=list_res
Y=np.array(ts.daily_count)
#print(len(X))
#print(len(Y))
Result=pd.DataFrame(columns=['X','Y'])
Result['X']=X
Result['Y']=Y
Result.head(20)
# Out:
#       X  Y
# 0     0  1
# 1     9  1
# 2    16  1
# 3    19  2
# 4    24  7
# 5    38  4
# 6    47  1
# 7    48  1
# 8    51  2
# 9    62  3
# 10   68  7
# 11   73  1
# 12   76  1
# 13   79  1
# 14   83  2
# 15   86  1
# 16   87  1
# 17   89  2
# 18   98  1
# 19  102  2

# %%
x=np.array(Result.X).reshape(-1,1)
y=np.array(Result.Y).reshape(-1,1)

model=MLPRegressor(hidden_layer_sizes=(10, 13), activation='logistic', solver='sgd', alpha=0.0001, batch_size='auto', learning_rate='constant', learning_rate_init=0.0001, power_t=0.5, max_iter=200, shuffle=True, random_state=None, tol=0.0001, verbose=True, warm_start=False, momentum=0.9, nesterovs_momentum=True, early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08, n_iter_no_change=1000)

model.fit(x,y)
# Out:
# /home/aimsadmin/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:1321: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 8.80032152
# Iteration 2, loss = 8.76493267
# Iteration 3, loss = 8.71047871
# Iteration 4, loss = 8.64060054
# Iteration 5, loss = 8.56226733
# Iteration 6, loss = 8.47788624
# Iteration 7, loss = 8.39113452
# Iteration 8, loss = 8.29950755
# Iteration 9, loss = 8.20864402
# Iteration 10, loss = 8.11747871
# Iteration 11, loss = 8.02676556
# Iteration 12, loss = 7.93540329
# Iteration 13, loss = 7.84361864
# Iteration 14, loss = 7.75592995
# Iteration 15, loss = 7.66837802
# Iteration 16, loss = 7.58238442
# Iteration 17, loss = 7.49820879
# Iteration 18, loss = 7.41831690
# Iteration 19, loss = 7.33640289
# Iteration 20, loss = 7.25827350
# ...

# %%
model.predict(np.array([87]).reshape(-1,1))
# Out:
# array([2.93190532])

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor

# %%
X=np.array([[1,1],[0,1],[2,3],[3,5]])
Y=np.array([0,0,1,1]).reshape(-1, 1)

model=MLPClassifier(hidden_layer_sizes=(5, 5), activation='relu', solver='adam', alpha=0.0001, batch_size='auto', learning_rate='constant', learning_rate_init=0.001, power_t=0.5, max_iter=200, shuffle=True, random_state=None, tol=0.0001, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08, n_iter_no_change=10)

# %%
model.fit(X,Y)
# Out:
# /home/aimsadmin/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/aimsadmin/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 5), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
# ...

# %%
model.predict(np.array([5,5]).reshape(1,-1))
# Out:
# array([0])

# %%
X=np.array([[1,1],[0,1],[2,3],[3,5]])
Y=np.array([1,2.2,3.4,4]).reshape(-1, 1)

model=MLPRegressor(hidden_layer_sizes=(5, 5), activation='relu', solver='adam', alpha=0.0001, batch_size='auto', learning_rate='constant', learning_rate_init=0.001, power_t=0.5, max_iter=800, shuffle=True, random_state=None, tol=0.0001, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08, n_iter_no_change=10)

# %%
model.fit(X,Y)
# Out:
# /home/aimsadmin/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:1321: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(5, 5), learning_rate='constant',
#              learning_rate_init=0.001, max_iter=800, momentum=0.9,
#              n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#              random_state=None, shuffle=True, solver='adam', tol=0.0001,
#              validation_fraction=0.1, verbose=False, warm_start=False)

# %%
model.predict(np.array([5,100]).reshape(1,-1))
# Out:
# array([82.30693966])

# %%
r=range(1,458)
list_res=[]
l=[*r]
for i in l:
    index=ts.index[:i]-ts.index[0]
    list_res.append(index)
X=index
Y=np.array(ts.daily_count)
X
Result=pd.DataFrame(columns=['X','Y'])
Result['X']=X
Result['Y']=Y
Result.head(20)
# Out:
#           X  Y
# 0    0 days  1
# 1    9 days  1
# 2   16 days  1
# 3   19 days  2
# 4   24 days  7
# 5   38 days  4
# 6   47 days  1
# 7   48 days  1
# 8   51 days  2
# 9   62 days  3
# 10  68 days  7
# 11  73 days  1
# 12  76 days  1
# 13  79 days  1
# 14  83 days  2
# 15  86 days  1
# 16  87 days  1
# 17  89 days  2
# 18  98 days  1
# 19 102 days  2

# %% [markdown]
# ## Time series plot

# %%
plt.figure(figsize=(10, 6))
ts.daily_count.plot()
plt.title('Plot of draw up count per day')
plt.ylabel('count per day')
plt.xlabel('Draw up date')
# plt.savefig('plotts.png')
plt.show()

# %% [markdown]
# ## Distribution plot

# %%
plt.figure(figsize=(10, 6))
sns.distplot(ts.daily_count, hist_kws={'alpha': 0.1}, kde = True, kde_kws={'alpha': 1})

# %% [markdown]
# We have a right skewed

# %% [markdown]
# ## Histograme

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ts.daily_count.hist(ax=ax, grid=True, bins=10, rwidth=0.8)

plt.title('Number of people drawing their Birth Certificate the same date')
ax.set_ylabel('Frequency of counts')
ax.set_xlabel('daily_count')
ax.set_xlim(0, 110)
plt.grid(axis='x', alpha=0.2)
plt.show()

# %% [markdown]
# ### Moving Average as Data Preparation

# %% [markdown]
# Moving average can be used as a data preparation technique to create a smoothed version of the original dataset.
#
# Smoothing is useful as a data preparation technique as it can reduce the random variation in the observations a.

# %% [markdown]
# Here we are taking different cases for window=2,4,6,8 to compare and take the best mooving average model and use for prediction

# %%
# weekly baseline
ts['baseline'] = ts.daily_count.shift(1)

# moving averages
ts['MVA2'] = ts.daily_count.rolling(2).mean().shift(1)
ts['MVA4'] = ts.daily_count.rolling(4).mean().shift(1)
ts['MVA6'] = ts.daily_count.rolling(6).mean().shift(1)
ts['MVA8'] = ts.daily_count.rolling(8).mean().shift(1)
ts.head(9)
# Out:
#               daily_count  baseline  MVA2  MVA4      MVA6  MVA8
# Draw.up.date
# 2010-01-02              1       NaN   NaN   NaN       NaN   NaN
# 2010-01-11              1       1.0   NaN   NaN       NaN   NaN
# 2010-01-18              1       1.0   1.0   NaN       NaN   NaN
# 2010-01-21              2       1.0   1.0   NaN       NaN   NaN
# 2010-01-26              7       2.0   1.5  1.25       NaN   NaN
# 2010-02-09              4       7.0   4.5  2.75       NaN   NaN
# 2010-02-18              1       4.0   5.5  3.50  2.666667   NaN
# 2010-02-19              1       1.0   2.5  3.50  2.666667   NaN
# 2010-02-22              2       1.0   1.0  3.25  2.666667  2.25

# %% [markdown]
# The reason that there are null values is because we take the average of first 2,4,6,8 weeks and shift of 1 week. Hence we have:

# %% [markdown]
# • MVA2 – A moving average of 2 weeks with a shift of 1 week.
#
# • MVA4 – A moving average of 4 weeks with a shift of 1 week.
#
# • MVA6 – A moving average of 6 weeks with a shift of 1 week.
#
# • MVA8 – A moving average of 8 weeks with a shift of 1 week.

# %% [markdown]
# ## Moving Average plots

# %% [markdown]
# Let us plot the small part of the data for the best visualization of the mooving average

# %%
ts50 = ts.daily_count[:50]

fig = plt.figure(figsize=(15,10))
n = 2
l = ['A', 'B', 'C', 'D']
for i in range(1, 5):
    ax = plt.subplot(2, 2, i)
    plt.subplots_adjust(wspace=0.3, hspace=0.8)
    ax.set_title('(%s) Plot of weekly count and MVA%d' % (l[i-1], n), pad=20)
    ax.set_ylabel('Daily count')
    ts50.plot(alpha=0.7, lw=2)
    ts50.rolling(n).mean().shift(1).plot(lw=3)
    ax.set_xlabel('draw up date')
    plt.legend(['count', 'MVA%d' % n])
    n = n + 2

# %% [markdown]
# The plot of MVA2 shows a loss of two first
# because we are doing the moving average of two weeks and forward shift of 1 week. The moving average of
# two weeks which will make week one have an empty value and a forward shift will push this further into
# week three. Then in MVA2 we will have two first weeks with empty values, in MVA4 four first weeks with empty values, and the same process for MVA6 and MVA8

# %%
ts.drop(ts.index[:8], inplace=True)
ts.head(8)
# Out:
#               daily_count  baseline  MVA2  MVA4      MVA6   MVA8
# Draw.up.date
# 2010-02-22              2       1.0   1.0  3.25  2.666667  2.250
# 2010-03-05              3       2.0   1.5  2.00  2.833333  2.375
# 2010-03-11              7       3.0   2.5  1.75  3.000000  2.625
# 2010-03-16              1       7.0   5.0  3.25  3.000000  3.375
# 2010-03-19              1       1.0   4.0  3.25  2.500000  3.250
# 2010-03-22              1       1.0   1.0  3.00  2.500000  2.500
# 2010-03-26              2       1.0   1.0  2.50  2.500000  2.125
# 2010-03-29              1       2.0   1.5  1.25  2.500000  2.250

# %% [markdown]
# ## Prediction performance function

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def prediction_performance(model, test_labels, test_features):
    # Use the model's predict method on the test data
    predictions = model.predict(test_features)

    # Calculate the mean absolute errors
    mae = round(mean_absolute_error(test_labels, predictions), 1)
    
    # Calculate the root mean square error
    rms = round(np.sqrt(mean_squared_error(test_labels, predictions)), 1)

    # Calculate mean absolute percentage error (MAPE)
    errors = abs(predictions - test_labels)
    mape = None
    if 0 not in test_labels:
        mape = round(np.mean(100 * (errors / test_labels)), 1)    
        
    # Calculate R2
    #r2 = round(r2_score(test_labels, predictions), 2)
    
    return (mae, rms, mape)#, r2)

# %% [markdown]
# ## Setting features and labels

# %%
# Labels are the values we want to predict
labels = np.array(ts.daily_count)

# Remove the labels from the features
# axis 1 refers to the columns
features = ts
features = features.drop(['daily_count'], axis = 1)

# Saving feature names for later use
feature_list = list(features.columns)

# Convert to numpy array
features = np.array(features)

print('Features shape:\t', features.shape)
print('Labels shape:\t', labels.shape)
# Out:
# Features shape:	 (449, 5)
# Labels shape:	 (449,)

# %% [markdown]
# ## Splitting data into train set and test set

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, \
    test_labels = train_test_split(features, labels, test_size = 0.2, random_state=42)

print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:\t', train_labels.shape)
print('Testing Features Shape:\t', test_features.shape)
print('Testing Labels Shape:\t', test_labels.shape)
# Out:
# Training Features Shape: (359, 5)
# Training Labels Shape:	 (359,)
# Testing Features Shape:	 (90, 5)
# Testing Labels Shape:	 (90,)

# %% [markdown]
# ## Baseline prediction performance

# %% [markdown]
# Mean Absolute Error: this is an interpretable metric because it has the same unit of measurment as the initial series, $[0,+\infty)$
#
# $MAE=\frac{\sum_{i=1}^{n}|y_i - \hat{y}_i|}{n}$
#
# Mean Squared Error: the most commonly used metric that gives a higher penalty to large errors and vice versa, $[0,+\infty)$
#
# $MSE=\frac{1}{n}\sum_{i=1}^{n}(y_i - \hat{y}_i)^2$  hence
#
# $RMSE=\sqrt{MSE}$
#
# Mean Absolute Percentage Error:  is computed as a percentage, which is very convenient when you want to explain the quality of the model to management, $[0,+\infty)$
#
# $MAPE=\frac{100}{n}\sum_{i=1}^{n}\frac{|y_i - \hat{y}_i|}{y_i}$

# %%
# The baseline prediction 
baseline_preds = test_features[:, feature_list.index('baseline')]
#baseline_preds = baseline_preds.astype(int)

# Baseline errors, and display average baseline error
errors = abs(baseline_preds - test_labels)
print('MAE:\t', round(np.mean(errors), 1))

# Calculate the root mean square error
rms = np.sqrt(mean_squared_error(test_labels, baseline_preds))
print('RMSE:\t', round(rms, 1))

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
print('MAPE:\t', round(np.mean(mape), 1), '%.')
# Out:
# MAE:	 2.2
# RMSE:	 3.4
# MAPE:	 96.9 %.

# %% [markdown]
# ## Moving averages as predictions

# %%
for mva in ['MVA2', 'MVA4', 'MVA6', 'MVA8']:
    print('----- {} -----'.format(mva))
    # The baseline prediction 
    baseline_preds = test_features[:, feature_list.index(mva)]
    #baseline_preds = baseline_preds.astype(int)

    # Baseline errors, and display average baseline error
    errors = abs(baseline_preds - test_labels)
    print('MAE:\t', round(np.mean(errors), 2))

    # Calculate the root mean square error
    rms = np.sqrt(mean_squared_error(test_labels, baseline_preds))
    print('RMSE:\t', round(rms, 2))

    # Calculate mean absolute percentage error (MAPE)
    mape = 100 * (errors / test_labels)
    print('MAPE:\t', round(np.mean(mape), 2), '%.')
# Out:
# ----- MVA2 -----
# MAE:	 2.12
# RMSE:	 3.21
# MAPE:	 97.22 %.
# ----- MVA4 -----
# MAE:	 2.06
# RMSE:	 3.01
# MAPE:	 93.08 %.
# ----- MVA6 -----
# MAE:	 2.05
# RMSE:	 2.99
# MAPE:	 95.5 %.
# ----- MVA8 -----
# MAE:	 1.98
# RMSE:	 2.96
# MAPE:	 89.77 %.

# %%
ts=pd.read_csv("ts.csv", delimiter=',')

from datetime import datetime
con=ts['Draw.up.date']
ts['Draw.up.date']=pd.to_datetime(ts['Draw.up.date'])
ts.set_index('Draw.up.date', inplace=True)
# weekly baseline
ts['baseline'] = ts.daily_count.shift(1)

#ts2=pd.DataFrame(index=ts.index)
listpas=[2,4,6,8]
list_shift=[1,2]
list_methods=[]
list_methods_with_baseline=['Baseline']
for pas in listpas:
    for shift in list_shift:
        method='MVA_pas_'+str(pas)+'_shift_'+str(shift)
        list_methods.append(method)
        list_methods_with_baseline.append(method)
        ts[method] = ts.daily_count.rolling(pas).mean().shift(shift)
ts.drop(ts.index[:listpas[-1]-1+list_shift[-1]], inplace=True)

#ts=ts2
# Labels are the values we want to predict
labels = np.array(ts.daily_count)

# Remove the labels from the features
# axis 1 refers to the columns
features = ts
features = features.drop(['daily_count'], axis = 1)

# Saving feature names for later use
feature_list = list(features.columns)

# Convert to numpy array
features = np.array(features)

#print('Features shape:\t', features.shape)
#print('Labels shape:\t', labels.shape)

# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, \
    test_labels = train_test_split(features, labels, test_size = 0.2, random_state=42)

#print('Training Features Shape:', train_features.shape)
#print('Training Labels Shape:\t', train_labels.shape)
#print('Testing Features Shape:\t', test_features.shape)
#print('Testing Labels Shape:\t', test_labels.shape)

# The baseline prediction 
baseline_preds = test_features[:, feature_list.index('baseline')]
#baseline_preds = baseline_preds.astype(int)

# Baseline errors, and display average baseline error
errors = abs(baseline_preds - test_labels)
MAE_baseline= round(np.mean(errors), 1)
#print('MAE:\t', round(np.mean(errors), 1))

# Calculate the root mean square error
rms = np.sqrt(mean_squared_error(test_labels, baseline_preds))
RMSE_baseline=round(rms, 1)
#print('RMSE:\t', round(rms, 1))

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
MAPE_baseline=round(np.mean(mape), 1)
#print('MAPE:\t', round(np.mean(mape), 1), '%.')

Results=pd.DataFrame(columns=['Methods','MAE','RMSE','MAPE (%)'])
MAE_list=[MAE_baseline]
RMSE_list=[RMSE_baseline]
MAPE_list=[MAPE_baseline]
for mva in list_methods:
    #print('----- {} -----'.format(mva))
    # The baseline prediction d
    baseline_preds = test_features[:, feature_list.index(mva)]
    #baseline_preds = baseline_preds.astype(int)

    # Baseline errors, and display average baseline error
    errors = abs(baseline_preds - test_labels)
    MAE=round(np.mean(errors), 2)
    #print('MAE:\t', round(np.mean(errors), 2))

    # Calculate the root mean square error
    rms = np.sqrt(mean_squared_error(test_labels, baseline_preds))
    RMSE=round(rms, 2)
    #print('RMSE:\t', round(rms, 2))

    # Calculate mean absolute percentage error (MAPE)
    mape = 100 * (errors / test_labels)
    MAPE=round(np.mean(mape), 2)
    #print('MAPE:\t', round(np.mean(mape), 2), '%.')
    MAE_list.append(MAE)
    RMSE_list.append(RMSE)
    MAPE_list.append(MAPE)

Results['Methods']=list_methods_with_baseline
Results['MAE']=MAE_list
Results['RMSE'] = RMSE_list
Results['MAPE (%)']= MAPE_list

Results
# Out:
#              Methods   MAE  RMSE  MAPE (%)
# 0           Baseline  2.20  3.20     98.90
# 1  MVA_pas_2_shift_1  2.11  3.13    100.80
# 2  MVA_pas_2_shift_2  2.28  3.25    108.57
# 3  MVA_pas_4_shift_1  1.98  2.87     93.36
# 4  MVA_pas_4_shift_2  1.90  2.77     90.60
# 5  MVA_pas_6_shift_1  1.79  2.70     83.68
# 6  MVA_pas_6_shift_2  1.90  2.80     85.79
# 7  MVA_pas_8_shift_1  1.82  2.72     84.51
# 8  MVA_pas_8_shift_2  1.87  2.75     85.25

# %% [markdown]
# Based on those results, the MVA8 is the best because it has errors less than others models Baseline,MVA2,MVA4 and MVA6

# %% [markdown]
# # AR AND ARIMA MODEL FOR PREDICTION

# %%
f=ts['MVA8']
f
# Out:
# Draw.up.date
# 2010-02-22    2.250
# 2010-03-05    2.375
# 2010-03-11    2.625
# 2010-03-16    3.375
# 2010-03-19    3.250
#               ...
# 2019-08-05    4.250
# 2019-10-05    3.625
# 2019-11-04    3.625
# 2019-12-03    3.250
# 2019-12-06    3.500
# Name: MVA8, Length: 449, dtype: float64

# %%
len(f)
# Out:
# 449

# %%
r=range(1,450)
list_res=[]
l=[*r]
for i in l:
    index=ts.index[:i]-ts.index[0]
    list_res.append(index)
X1=index
Y1=np.array(ts.MVA8)
X1
Result=pd.DataFrame(columns=['X1','Y1'])
Result['X1']=X1
Result['Y1']=Y1
Result.head(20)
# Out:
#          X1     Y1
# 0    0 days  2.250
# 1   11 days  2.375
# 2   17 days  2.625
# 3   22 days  3.375
# 4   25 days  3.250
# 5   28 days  2.500
# 6   32 days  2.125
# 7   35 days  2.250
# 8   36 days  2.250
# 9   38 days  2.125
# 10  47 days  2.000
# 11  51 days  1.250
# 12  56 days  1.375
# 13  67 days  1.375
# 14  68 days  1.625
# 15  72 days  1.500
# 16  77 days  1.625
# 17  82 days  1.625
# 18  93 days  1.750
# 19 102 days  1.750

# %%
plt.figure(figsize=(10, 6))
f.plot()
plt.title('Plot of MVA8')
plt.ylabel('count per day')
plt.xlabel('Draw up date')
# plt.savefig('plotts.png')
plt.show()

# %% [markdown]
# ## AR Model

# %%
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
# split dataset
X = f.values
#train, test = X,X
train, test = X, X
# train autoregression
model = AR(train)
model_fit = model.fit()
window = model_fit.k_ar
coef = model_fit.params
# walk forward over time steps in test
history = list(train[len(train)-window:])
#history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test)):
    length = len(history)
    lag = [history[i] for i in range(length-window,length)]
    yhat = coef[0]
    for d in range(window):
        yhat += coef[d+1] * lag[window-d-1]
    obs = test[t]
    predictions.append(yhat)
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))

error = np.sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % error)
# plot
test_dataframe=pd.DataFrame(index=f.index)
test_dataframe['date']=test

predictions_dataframe=pd.DataFrame(index=f.index)
predictions_dataframe['date']=predictions

plt.figure(figsize=(10, 6))
plt.plot(test_dataframe)
plt.plot(predictions_dataframe, color='red')

plt.title('Plot of AR model')
plt.ylabel('count per day')
plt.xlabel('Draw up date')
# plt.savefig('plotts.png')
plt.show()
# Out:
# RMSE: 0.395

# %% [markdown]
# ## ARIMA Model

# %%
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

fig = plt.figure(figsize=(10,6))
autocorrelation_plot(f)
pyplot.show()

# %% [markdown]
# There is some positives correlations

# %%
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
 
# fit model
model = ARIMA(f, order=(1,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
fig = plt.figure(figsize=(10,6))

residuals = DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
# /home/aimsadmin/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/aimsadmin/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:                 D.MVA8   No. Observations:                  448
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -300.907
# Method:                       css-mle   S.D. of innovations              0.474
# Date:                Sat, 02 Nov 2019   AIC                            609.814
# ...

# %% [markdown]
# The distribution of the residual errors is displayed. The results show that indeed there is a bias in the prediction (a non-zero mean in the residuals).
#
# The density plot of the residual error values, suggesting the errors are Gaussian, and centered on zero.

# %% [markdown]
# ### Implementation of the Arima model

# %%
from matplotlib import pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
 
X = f.values
#size = int(len(X)*0.1 ) 
#train, test = X[0:395], X
train, test = X, X
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(1,1,1))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))
#errors
#errors = abs(baseline_preds - test)
#print('MAE:\t', round(np.mean(errors), 1))
error = np.sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % error)
#mape = 100 * (errors / test)
#print('MAPE:\t', round(np.mean(mape), 2), '%.')
# plot
test_dataframe=pd.DataFrame(index=f.index)
test_dataframe['date']=test

predictions_dataframe=pd.DataFrame(index=f.index)
predictions_dataframe['date']=predictions

plt.figure(figsize=(10, 6))
plt.plot(test_dataframe)
plt.plot(predictions_dataframe, color='red')

plt.title('Plot of ARIMA model')
plt.ylabel('count per day')
plt.xlabel('Draw up date')

plt.show()
# Out:
# RMSE: 0.478

# %% [markdown]
# AR Model is the best because he has the smallest Root Mean Squared Error (RMSE)

# %% [markdown]
# ## MULTILAYER PERCEPTRON (MLP)

# %% [markdown]
# ### Correlation matrix

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = ts.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
